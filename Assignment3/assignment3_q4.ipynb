# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import minimize

# %%
setosa = []  
versicolor = []

# %%
data = pd.read_csv("iris.csv")
print(data.head())
column = ['petal.length', 'sepal.width']
versicolor = data[column][50 : 100].copy()
setosa = data[column][0 : 50].copy()
cla=['variety']
set_class=data[cla][0:100]
print(setosa.head())
print(versicolor.head())
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
#    petal.length  sepal.width
# 0           1.4          3.5
# 1           1.4          3.0
# 2           1.3          3.2
# 3           1.5          3.1
# 4           1.4          3.6
#     petal.length  sepal.width
# 50           4.7          3.2
# 51           4.5          3.2
# 52           4.9          3.1
# 53           4.0          2.3
# 54           4.6          2.8

# %%
w1 = []
w2 = []
for index, row in setosa.iterrows():
    w1.append([row[0], row[1]])
w1=np.array(w1)
print(w1)
print(w1.shape)
for index, row in versicolor.iterrows():
    w2.append([row[0], row[1]])
w2 = np.array(w2)
print(w2)
print(w2.shape)
# Out:
# [[1.4 3.5]
#  [1.4 3. ]
#  [1.3 3.2]
#  [1.5 3.1]
#  [1.4 3.6]
#  [1.7 3.9]
#  [1.4 3.4]
#  [1.5 3.4]
#  [1.4 2.9]
#  [1.5 3.1]
#  [1.5 3.7]
#  [1.6 3.4]
#  [1.4 3. ]
#  [1.1 3. ]
#  [1.2 4. ]
#  [1.5 4.4]
#  [1.3 3.9]
#  [1.4 3.5]
#  [1.7 3.8]
#  [1.5 3.8]
#  [1.7 3.4]
#  [1.5 3.7]
#  [1.  3.6]
#  [1.7 3.3]
#  [1.9 3.4]
#  [1.6 3. ]
#  [1.6 3.4]
#  [1.5 3.5]
#  [1.4 3.4]
#  [1.6 3.2]
#  [1.6 3.1]
#  [1.5 3.4]
#  [1.5 4.1]
#  [1.4 4.2]
#  [1.5 3.1]
#  [1.2 3.2]
#  [1.3 3.5]
#  [1.4 3.6]
#  [1.3 3. ]
#  [1.5 3.4]
#  [1.3 3.5]
#  [1.3 2.3]
#  [1.3 3.2]
#  [1.6 3.5]
#  [1.9 3.8]
#  [1.4 3. ]
#  [1.6 3.8]
#  [1.4 3.2]
#  [1.5 3.7]
#  [1.4 3.3]]
# (50, 2)
# [[4.7 3.2]
#  [4.5 3.2]
#  [4.9 3.1]
#  [4.  2.3]
#  [4.6 2.8]
#  [4.5 2.8]
#  [4.7 3.3]
#  [3.3 2.4]
#  [4.6 2.9]
#  [3.9 2.7]
#  [3.5 2. ]
#  [4.2 3. ]
#  [4.  2.2]
#  [4.7 2.9]
#  [3.6 2.9]
#  [4.4 3.1]
#  [4.5 3. ]
#  [4.1 2.7]
#  [4.5 2.2]
#  [3.9 2.5]
#  [4.8 3.2]
#  [4.  2.8]
#  [4.9 2.5]
#  [4.7 2.8]
#  [4.3 2.9]
#  [4.4 3. ]
#  [4.8 2.8]
#  [5.  3. ]
#  [4.5 2.9]
#  [3.5 2.6]
#  [3.8 2.4]
#  [3.7 2.4]
#  [3.9 2.7]
#  [5.1 2.7]
#  [4.5 3. ]
#  [4.5 3.4]
#  [4.7 3.1]
#  [4.4 2.3]
#  [4.1 3. ]
#  [4.  2.5]
#  [4.4 2.6]
#  [4.6 3. ]
#  [4.  2.6]
#  [3.3 2.3]
#  [4.2 2.7]
#  [4.2 3. ]
#  [4.2 2.9]
#  [4.3 2.9]
#  [3.  2.5]
#  [4.1 2.8]]
# (50, 2)

# %%
data1 = []
for i in range(len(w1)):
    data1.append([1, w1[i][0], w1[i][1]])
    data1.append([-1, -w2[i][0], -w2[i][1]])
data1 = np.array(data1)
print(data1.shape)
# Out:
# (100, 3)

# %%
data2 = []
for i in range(len(w2)):
    data2.append([1, w2[i][0], w2[i][1]])
    data2.append([-1, -w1[i][0], -w1[i][1]])
data2 = np.array(data2)
print(data2.shape)
# Out:
# (100, 3)

# %%
lr=0.01
k=0
Q=0
a = np.array([0, 0, 0])
missclasified_vectors = True
epoch = 1

# %%
while(((missclasified_vectors) or (not(k == 0))) and (epoch < 10)):
        if(k == 0):
            print("\n\n\nIteration : ", epoch)
            epoch = epoch + 1
            missclasified_vectors = False
        print("Data index : ", k)
        print("weights : ", a)
        print("Data point : ", np.array(data1[k]))
        dot_product = np.dot(a, data1[k])
        print("The dot product is : ", dot_product)
        if(dot_product <= 0):            
            a = a + lr * data1[k]
            missclasified_vectors = True
        k = (k + 1) % (len(data1))
print("***************Perceptron*****************")
print("weights are : ", a)
x_vec = np.linspace(0, 10, 5)
y_vec = ((a[1] * x_vec) + a[0])/a[2]
y_vec = -y_vec 
f, ax = plt.subplots(figsize=(7, 7))
c1, c2, c3 = "#3366AA", "#AA3333", 'm'
ax.scatter(*w1.T, c=c1,s = 10, label = "w1")
ax.legend()
ax.scatter(*w2.T, c=c2, marker="D", label = "w2")
ax.legend()
ax.set_title('Perceptron')
plt.plot(x_vec, y_vec, 'g--')
plt.show()
# Out:
# Iteration :  1
# Data index :  0
# weights :  [0 0 0]
# Data point :  [1.  1.4 3.5]
# The dot product is :  0.0
# Data index :  1
# weights :  [0.01  0.014 0.035]
# Data point :  [-1.  -4.7 -3.2]
# The dot product is :  -0.18780000000000002
# Data index :  2
# weights :  [ 0.    -0.033  0.003]
# Data point :  [1.  1.4 3. ]
# The dot product is :  -0.03719999999999999
# Data index :  3
# weights :  [ 0.01  -0.019  0.033]
# Data point :  [-1.  -4.5 -3.2]
# The dot product is :  -0.030099999999999988
# Data index :  4
# weights :  [ 0.    -0.064  0.001]
# Data point :  [1.  1.3 3.2]
# The dot product is :  -0.08
# Data index :  5
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.9 -3.1]
# The dot product is :  0.13760000000000003
# Data index :  6
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.1]
# The dot product is :  0.035799999999999985
# Data index :  7
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.  -2.3]
# The dot product is :  0.11810000000000001
# Data index :  8
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3.6]
# The dot product is :  0.0574
# Data index :  9
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.6 -2.8]
# The dot product is :  0.13219999999999998
# Data index :  10
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.7 3.9]
# The dot product is :  0.052000000000000005
# Data index :  11
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.5 -2.8]
# The dot product is :  0.1271
# Data index :  12
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3.4]
# The dot product is :  0.050800000000000005
# Data index :  13
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.7 -3.3]
# The dot product is :  0.12080000000000002
# Data index :  14
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.4]
# The dot product is :  0.04569999999999999
# Data index :  15
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.3 -2.4]
# The dot product is :  0.07909999999999999
# Data index :  16
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 2.9]
# The dot product is :  0.034300000000000004
# Data index :  17
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.6 -2.9]
# The dot product is :  0.1289
# Data index :  18
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.1]
# The dot product is :  0.035799999999999985
# Data index :  19
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.9 -2.7]
# The dot product is :  0.0998
# Data index :  20
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.7]
# The dot product is :  0.0556
# Data index :  21
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.5 -2. ]
# The dot product is :  0.10250000000000001
# Data index :  22
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.6 3.4]
# The dot product is :  0.0406
# Data index :  23
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.2 -3. ]
# The dot product is :  0.10520000000000002
# Data index :  24
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3. ]
# The dot product is :  0.0376
# Data index :  25
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.  -2.2]
# The dot product is :  0.1214
# Data index :  26
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.1 3. ]
# The dot product is :  0.052899999999999996
# Data index :  27
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.7 -2.9]
# The dot product is :  0.134
# Data index :  28
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.2 4. ]
# The dot product is :  0.08080000000000001
# Data index :  29
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.6 -2.9]
# The dot product is :  0.0779
# Data index :  30
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 4.4]
# The dot product is :  0.0787
# Data index :  31
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.4 -3.1]
# The dot product is :  0.11210000000000003
# Data index :  32
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.3 3.9]
# The dot product is :  0.07239999999999999
# Data index :  33
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.5 -3. ]
# The dot product is :  0.1205
# Data index :  34
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3.5]
# The dot product is :  0.0541
# Data index :  35
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.1 -2.7]
# The dot product is :  0.10999999999999999
# Data index :  36
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.7 3.8]
# The dot product is :  0.04870000000000001
# Data index :  37
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.5 -2.2]
# The dot product is :  0.14689999999999998
# Data index :  38
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.8]
# The dot product is :  0.058899999999999994
# Data index :  39
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.9 -2.5]
# The dot product is :  0.10640000000000001
# Data index :  40
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.7 3.4]
# The dot product is :  0.035500000000000004
# Data index :  41
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.8 -3.2]
# The dot product is :  0.12919999999999998
# Data index :  42
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.7]
# The dot product is :  0.0556
# Data index :  43
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.  -2.8]
# The dot product is :  0.10160000000000001
# Data index :  44
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.  3.6]
# The dot product is :  0.07780000000000001
# Data index :  45
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.9 -2.5]
# The dot product is :  0.15740000000000004
# Data index :  46
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.7 3.3]
# The dot product is :  0.03219999999999999
# Data index :  47
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.7 -2.8]
# The dot product is :  0.13730000000000003
# Data index :  48
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.9 3.4]
# The dot product is :  0.025300000000000003
# Data index :  49
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.3 -2.9]
# The dot product is :  0.11359999999999998
# Data index :  50
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.6 3. ]
# The dot product is :  0.027399999999999994
# Data index :  51
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.4 -3. ]
# The dot product is :  0.11540000000000003
# Data index :  52
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.6 3.4]
# The dot product is :  0.0406
# Data index :  53
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.8 -2.8]
# The dot product is :  0.14240000000000003
# Data index :  54
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.5]
# The dot product is :  0.04899999999999999
# Data index :  55
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1. -5. -3.]
# The dot product is :  0.146
# Data index :  56
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3.4]
# The dot product is :  0.050800000000000005
# Data index :  57
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.5 -2.9]
# The dot product is :  0.1238
# Data index :  58
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.6 3.2]
# The dot product is :  0.034
# Data index :  59
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.5 -2.6]
# The dot product is :  0.08270000000000001
# Data index :  60
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.6 3.1]
# The dot product is :  0.03069999999999999
# Data index :  61
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.8 -2.4]
# The dot product is :  0.10459999999999998
# Data index :  62
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.4]
# The dot product is :  0.04569999999999999
# Data index :  63
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.7 -2.4]
# The dot product is :  0.09950000000000002
# Data index :  64
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 4.1]
# The dot product is :  0.06879999999999999
# Data index :  65
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.9 -2.7]
# The dot product is :  0.0998
# Data index :  66
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 4.2]
# The dot product is :  0.07719999999999999
# Data index :  67
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -5.1 -2.7]
# The dot product is :  0.16099999999999998
# Data index :  68
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.1]
# The dot product is :  0.035799999999999985
# Data index :  69
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.5 -3. ]
# The dot product is :  0.1205
# Data index :  70
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.2 3.2]
# The dot product is :  0.05440000000000001
# Data index :  71
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.5 -3.4]
# The dot product is :  0.10729999999999999
# Data index :  72
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.3 3.5]
# The dot product is :  0.059199999999999996
# Data index :  73
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.7 -3.1]
# The dot product is :  0.1274
# Data index :  74
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3.6]
# The dot product is :  0.0574
# Data index :  75
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.4 -2.3]
# The dot product is :  0.13850000000000004
# Data index :  76
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.3 3. ]
# The dot product is :  0.042699999999999995
# Data index :  77
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.1 -3. ]
# The dot product is :  0.1001
# Data index :  78
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.4]
# The dot product is :  0.04569999999999999
# Data index :  79
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.  -2.5]
# The dot product is :  0.1115
# Data index :  80
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.3 3.5]
# The dot product is :  0.059199999999999996
# Data index :  81
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.4 -2.6]
# The dot product is :  0.12860000000000005
# Data index :  82
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.3 2.3]
# The dot product is :  0.019599999999999985
# Data index :  83
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.6 -3. ]
# The dot product is :  0.1256
# Data index :  84
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.3 3.2]
# The dot product is :  0.049300000000000004
# Data index :  85
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.  -2.6]
# The dot product is :  0.1082
# Data index :  86
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.6 3.5]
# The dot product is :  0.043899999999999995
# Data index :  87
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.3 -2.3]
# The dot product is :  0.0824
# Data index :  88
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.9 3.8]
# The dot product is :  0.038500000000000006
# Data index :  89
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.2 -2.7]
# The dot product is :  0.11510000000000001
# Data index :  90
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3. ]
# The dot product is :  0.0376
# Data index :  91
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.2 -3. ]
# The dot product is :  0.10520000000000002
# Data index :  92
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.6 3.8]
# The dot product is :  0.0538
# Data index :  93
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.2 -2.9]
# The dot product is :  0.10850000000000001
# Data index :  94
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3.2]
# The dot product is :  0.04420000000000001
# Data index :  95
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.3 -2.9]
# The dot product is :  0.11359999999999998
# Data index :  96
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.7]
# The dot product is :  0.0556
# Data index :  97
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.  -2.5]
# The dot product is :  0.06050000000000001
# Data index :  98
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3.3]
# The dot product is :  0.047499999999999994
# Data index :  99
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.1 -2.8]
# The dot product is :  0.1067
#
#
#
# Iteration :  2
# Data index :  0
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3.5]
# The dot product is :  0.0541
# Data index :  1
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.7 -3.2]
# The dot product is :  0.1241
# Data index :  2
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3. ]
# The dot product is :  0.0376
# Data index :  3
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.5 -3.2]
# The dot product is :  0.11389999999999999
# Data index :  4
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.3 3.2]
# The dot product is :  0.049300000000000004
# Data index :  5
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.9 -3.1]
# The dot product is :  0.13760000000000003
# Data index :  6
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.1]
# The dot product is :  0.035799999999999985
# Data index :  7
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.  -2.3]
# The dot product is :  0.11810000000000001
# Data index :  8
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3.6]
# The dot product is :  0.0574
# Data index :  9
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.6 -2.8]
# The dot product is :  0.13219999999999998
# Data index :  10
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.7 3.9]
# The dot product is :  0.052000000000000005
# Data index :  11
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.5 -2.8]
# The dot product is :  0.1271
# Data index :  12
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3.4]
# The dot product is :  0.050800000000000005
# Data index :  13
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.7 -3.3]
# The dot product is :  0.12080000000000002
# Data index :  14
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.4]
# The dot product is :  0.04569999999999999
# Data index :  15
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.3 -2.4]
# The dot product is :  0.07909999999999999
# Data index :  16
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 2.9]
# The dot product is :  0.034300000000000004
# Data index :  17
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.6 -2.9]
# The dot product is :  0.1289
# Data index :  18
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.1]
# The dot product is :  0.035799999999999985
# Data index :  19
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.9 -2.7]
# The dot product is :  0.0998
# Data index :  20
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.7]
# The dot product is :  0.0556
# Data index :  21
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.5 -2. ]
# The dot product is :  0.10250000000000001
# Data index :  22
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.6 3.4]
# The dot product is :  0.0406
# Data index :  23
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.2 -3. ]
# The dot product is :  0.10520000000000002
# Data index :  24
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3. ]
# The dot product is :  0.0376
# Data index :  25
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.  -2.2]
# The dot product is :  0.1214
# Data index :  26
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.1 3. ]
# The dot product is :  0.052899999999999996
# Data index :  27
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.7 -2.9]
# The dot product is :  0.134
# Data index :  28
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.2 4. ]
# The dot product is :  0.08080000000000001
# Data index :  29
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.6 -2.9]
# The dot product is :  0.0779
# Data index :  30
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 4.4]
# The dot product is :  0.0787
# Data index :  31
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.4 -3.1]
# The dot product is :  0.11210000000000003
# Data index :  32
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.3 3.9]
# The dot product is :  0.07239999999999999
# Data index :  33
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.5 -3. ]
# The dot product is :  0.1205
# Data index :  34
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3.5]
# The dot product is :  0.0541
# Data index :  35
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.1 -2.7]
# The dot product is :  0.10999999999999999
# Data index :  36
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.7 3.8]
# The dot product is :  0.04870000000000001
# Data index :  37
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.5 -2.2]
# The dot product is :  0.14689999999999998
# Data index :  38
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.8]
# The dot product is :  0.058899999999999994
# Data index :  39
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.9 -2.5]
# The dot product is :  0.10640000000000001
# Data index :  40
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.7 3.4]
# The dot product is :  0.035500000000000004
# Data index :  41
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.8 -3.2]
# The dot product is :  0.12919999999999998
# Data index :  42
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.7]
# The dot product is :  0.0556
# Data index :  43
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.  -2.8]
# The dot product is :  0.10160000000000001
# Data index :  44
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.  3.6]
# The dot product is :  0.07780000000000001
# Data index :  45
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.9 -2.5]
# The dot product is :  0.15740000000000004
# Data index :  46
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.7 3.3]
# The dot product is :  0.03219999999999999
# Data index :  47
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.7 -2.8]
# The dot product is :  0.13730000000000003
# Data index :  48
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.9 3.4]
# The dot product is :  0.025300000000000003
# Data index :  49
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.3 -2.9]
# The dot product is :  0.11359999999999998
# Data index :  50
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.6 3. ]
# The dot product is :  0.027399999999999994
# Data index :  51
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.4 -3. ]
# The dot product is :  0.11540000000000003
# Data index :  52
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.6 3.4]
# The dot product is :  0.0406
# Data index :  53
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.8 -2.8]
# The dot product is :  0.14240000000000003
# Data index :  54
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.5]
# The dot product is :  0.04899999999999999
# Data index :  55
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1. -5. -3.]
# The dot product is :  0.146
# Data index :  56
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3.4]
# The dot product is :  0.050800000000000005
# Data index :  57
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.5 -2.9]
# The dot product is :  0.1238
# Data index :  58
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.6 3.2]
# The dot product is :  0.034
# Data index :  59
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.5 -2.6]
# The dot product is :  0.08270000000000001
# Data index :  60
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.6 3.1]
# The dot product is :  0.03069999999999999
# Data index :  61
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.8 -2.4]
# The dot product is :  0.10459999999999998
# Data index :  62
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.4]
# The dot product is :  0.04569999999999999
# Data index :  63
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.7 -2.4]
# The dot product is :  0.09950000000000002
# Data index :  64
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 4.1]
# The dot product is :  0.06879999999999999
# Data index :  65
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.9 -2.7]
# The dot product is :  0.0998
# Data index :  66
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 4.2]
# The dot product is :  0.07719999999999999
# Data index :  67
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -5.1 -2.7]
# The dot product is :  0.16099999999999998
# Data index :  68
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.1]
# The dot product is :  0.035799999999999985
# Data index :  69
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.5 -3. ]
# The dot product is :  0.1205
# Data index :  70
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.2 3.2]
# The dot product is :  0.05440000000000001
# Data index :  71
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.5 -3.4]
# The dot product is :  0.10729999999999999
# Data index :  72
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.3 3.5]
# The dot product is :  0.059199999999999996
# Data index :  73
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.7 -3.1]
# The dot product is :  0.1274
# Data index :  74
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3.6]
# The dot product is :  0.0574
# Data index :  75
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.4 -2.3]
# The dot product is :  0.13850000000000004
# Data index :  76
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.3 3. ]
# The dot product is :  0.042699999999999995
# Data index :  77
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.1 -3. ]
# The dot product is :  0.1001
# Data index :  78
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.4]
# The dot product is :  0.04569999999999999
# Data index :  79
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.  -2.5]
# The dot product is :  0.1115
# Data index :  80
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.3 3.5]
# The dot product is :  0.059199999999999996
# Data index :  81
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.4 -2.6]
# The dot product is :  0.12860000000000005
# Data index :  82
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.3 2.3]
# The dot product is :  0.019599999999999985
# Data index :  83
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.6 -3. ]
# The dot product is :  0.1256
# Data index :  84
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.3 3.2]
# The dot product is :  0.049300000000000004
# Data index :  85
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.  -2.6]
# The dot product is :  0.1082
# Data index :  86
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.6 3.5]
# The dot product is :  0.043899999999999995
# Data index :  87
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.3 -2.3]
# The dot product is :  0.0824
# Data index :  88
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.9 3.8]
# The dot product is :  0.038500000000000006
# Data index :  89
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.2 -2.7]
# The dot product is :  0.11510000000000001
# Data index :  90
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3. ]
# The dot product is :  0.0376
# Data index :  91
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.2 -3. ]
# The dot product is :  0.10520000000000002
# Data index :  92
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.6 3.8]
# The dot product is :  0.0538
# Data index :  93
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.2 -2.9]
# The dot product is :  0.10850000000000001
# Data index :  94
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3.2]
# The dot product is :  0.04420000000000001
# Data index :  95
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.3 -2.9]
# The dot product is :  0.11359999999999998
# Data index :  96
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.5 3.7]
# The dot product is :  0.0556
# Data index :  97
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -3.  -2.5]
# The dot product is :  0.06050000000000001
# Data index :  98
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [1.  1.4 3.3]
# The dot product is :  0.047499999999999994
# Data index :  99
# weights :  [ 0.01  -0.051  0.033]
# Data point :  [-1.  -4.1 -2.8]
# The dot product is :  0.1067
# ***************Perceptron*****************
# weights are :  [ 0.01  -0.051  0.033]

# %%
z = []
data = []
alpha = []
c = 10
# def non_linearly_seperable_func(alpha):
#     global c
#     value = -func(alpha)
#     for i in range(len(alpha)):
#         value -= (1/(2 * c)) * (alpha[i] ** 2)
#     return (-value)



def func(alpha):
    alpha = np.array(alpha)
    value = np.sum(alpha)
    for i in range(len(alpha)):
        for j in range(len(alpha)):
            if(i == j):
                pass
            value -= 0.5 * (alpha[i] * alpha[j] * z[i] * z[j] * (data[i].T.dot(data[j])))
    return (-value)

def constraint(alpha):
    global z
    sum = 0
    for alpha_i, z_i in zip(alpha, z):
        sum += alpha_i * z_i
    return(sum)

def abs(num):
    if(num < 0):
        return(-num)
    else:
        return(num)

def svm():
    global z
    global alpha
    global w1
    global w2
    global data
    z = np.concatenate([np.ones(50), -np.ones(100)], axis = 0)
    print(len(z))
    data1 = np.concatenate([w1, w2], axis = 0)
    data2 = np.concatenate([w1, w2])
    # print("data : ", data1)
    max_solution = 0
    f, ax = plt.subplots(figsize=(7, 7))
    c1, c2 = "#3366AA", "#AA3333"
    for j in range(2):
        if(j == 0):
            data = data1
        else:
            data = data2
        consrt = {'type' : 'eq', 'fun' : constraint}
        alpha = np.zeros(len(data))
        print(len(alpha))
        if(j == 0):
            c = None
        else:
            c = 100
        b = (0.0000000000, c)
        bound = [b] * len(data)
        print(len(bound))
        sol = minimize(func, alpha, method = 'SLSQP', constraints = consrt, bounds = bound)
        print(sol)
        alpha = sol.x

        print("lagrange multiplier are : ", alpha)

        a = np.zeros(len(data[0]))
        for i in range(len(data)):
            a += alpha[i]*z[i]*data[i]
        if(j == 1):
            error = alpha / c
        else:
            error = np.zeros(len(alpha)) 
        bias = []                                          #finding the points that pass through the w.x + b = +/- 1
        for i in range(len(alpha)):
            for k in range(len(alpha)):
                if(i == k):
                    pass
                else:
                    if(abs(0.5 * (alpha[i] * alpha[k] * z[i] * z[k] * (data[i].T.dot(data[k])))) > 0.0001):
                        bias.append((1 - error[i])/z[i] - a.T.dot(data[i]))
                        
        bias = np.array(bias).mean()
        print("bias is ", bias)
        print("weight vector is : ", a)
        a = [bias, a[0] , a[1]] 
        if(j == 0):
            x_vec = np.linspace(1, 8, 5)
        else:
            x_vec = np.linspace(3, 8, 5)

        y_vec = ((a[1] * x_vec) + a[0])/a[2]
        y_vec = -y_vec
        if(j == 0):
            plt.plot(x_vec, y_vec, 'r--')
        else:
            plt.plot(x_vec, y_vec, 'b--')
        y_vec = y_vec + (1 / a[2])
        plt.plot(x_vec, y_vec, 'g--')
        y_vec = y_vec - (2/ a[2])
        plt.plot(x_vec, y_vec, 'g--')
        
    ax.scatter(*w1.T, c=c1,s = 10, label = "w1")
    ax.legend()
    ax.scatter(*w2.T, c=c2,s = 10, marker="D", label = "w2")
    ax.legend()
    plt.show()

# %%
 svm()
# Out:
# 150
# 100
# 100
#      fun: -1.0253060599127182
#      jac: array([-0.3600558 , -0.7029717 , -0.44005764, -0.76013613, -0.29147267,
#        -0.46296608, -0.42863894, -0.55438662, -0.77155483, -0.76013613,
#        -0.3486371 , -0.68013418, -0.70297158, -0.32572877,  0.23435533,
#         0.13144517,  0.04002464, -0.3600558 , -0.53154922, -0.28005385,
#        -0.80588186, -0.3486371 ,  0.21151793, -0.87446511, -1.05737722,
#        -0.95446706, -0.6801343 , -0.48580348, -0.42863894, -0.81730056,
#        -0.88588381, -0.55438673, -0.07430434,  0.12002647, -0.76013613,
#        -0.31431007, -0.23430824, -0.29147255, -0.57722402, -0.55438662,
#        -0.23430824, -1.05730629, -0.44005764, -0.61155105, -0.78304458,
#        -0.7029717 , -0.40580153, -0.56580532, -0.34863698, -0.49722219,
#         2.71547806,  2.4639827 ,  3.03555644,  2.45249307,  2.86406302,
#         2.73831534,  2.64689481,  1.5036763 ,  2.79547977,  2.05241263,
