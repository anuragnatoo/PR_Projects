# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def perceptron():
    w1 = np.array([[1, 1, 6], [1, 7, 2], [1, 8, 9], [1, 9, 9]])
    w2 = np.array([[1, 2, 1], [1, 2, 2], [1, 2, 4], [1, 7, 1]])
    data = np.concatenate([w1, -w2], axis = 0)
    print(data)
    w1 = np.array([[1, 6], [7, 2], [8, 9], [9, 9]])
    w2 = np.array([[2, 1], [2, 2], [2, 4], [7, 1]])
    total_epoch = [0, 0]
    for learning_rate in [0.1]:
        k = 0
        Q = 0                           #criterian theta
        a = np.array([0.1, 0.1, 0.1])            #weights
        mv = True
        epoch = 1
        while((mv) or not(k == 0)):
            if(k == 0):
                print("\n\n\nEpoch : ", epoch)
                epoch = epoch + 1
                mv = False
            print("Data index : ", k)
            print("weights : ", a)
            print("Data point : ", np.array(data[k]))
            dp = np.dot(a, data[k])
            print("The dot product is : ", dp)
            if(dp <= 0):            
                a = a + learning_rate * data[k]
                mv = True
            k = (k + 1) % (len(data))
    print("The final weight vector is : ", a)
    f, ax = plt.subplots(figsize=(7, 7))
    c1, c2 = "#3366AA", "#AA3333"
    ax.scatter(*w1.T, c=c1,s = 10, label = "w1")
    ax.legend()
    ax.scatter(*w2.T, c=c2, marker="D", label = "w2")
    ax.legend()
    x_vec = np.linspace(-2, 10, 5)
    y_vec = ((a[1] * x_vec) + a[0])/a[2]
    y_vec = -y_vec   
    plt.plot(x_vec, y_vec, 'r--')

    b = np.array([1, 1, 1, 1, 1, 1, 1, 1])
    print(data.shape)
    a = np.linalg.lstsq(data, b.transpose())
    a = np.array(a[0])
    x_vec = np.linspace(-2, 10, 5)
    y_vec = ((a[1] * x_vec) + a[0])/a[2]
    y_vec = -y_vec   
    plt.plot(x_vec, y_vec, 'b--')
    plt.show()

# %%
perceptron()
# Out:
# [[ 1  1  6]
#  [ 1  7  2]
#  [ 1  8  9]
#  [ 1  9  9]
#  [-1 -2 -1]
#  [-1 -2 -2]
#  [-1 -2 -4]
#  [-1 -7 -1]]
#
#
#
# Epoch :  1
# Data index :  0
# weights :  [0.1 0.1 0.1]
# Data point :  [1 1 6]
# The dot product is :  0.8
# Data index :  1
# weights :  [0.1 0.1 0.1]
# Data point :  [1 7 2]
# The dot product is :  1.0
# Data index :  2
# weights :  [0.1 0.1 0.1]
# Data point :  [1 8 9]
# The dot product is :  1.8
# Data index :  3
# weights :  [0.1 0.1 0.1]
# Data point :  [1 9 9]
# The dot product is :  1.9
# Data index :  4
# weights :  [0.1 0.1 0.1]
# Data point :  [-1 -2 -1]
# The dot product is :  -0.4
# Data index :  5
# weights :  [ 0.  -0.1  0. ]
# Data point :  [-1 -2 -2]
# The dot product is :  0.2
# Data index :  6
# weights :  [ 0.  -0.1  0. ]
# Data point :  [-1 -2 -4]
# The dot product is :  0.2
# Data index :  7
# weights :  [ 0.  -0.1  0. ]
# Data point :  [-1 -7 -1]
# The dot product is :  0.7000000000000001
#
#
#
# Epoch :  2
# Data index :  0
# weights :  [ 0.  -0.1  0. ]
# Data point :  [1 1 6]
# The dot product is :  -0.1
# Data index :  1
# weights :  [0.1 0.  0.6]
# Data point :  [1 7 2]
# The dot product is :  1.3000000000000003
# Data index :  2
# weights :  [0.1 0.  0.6]
# Data point :  [1 8 9]
# The dot product is :  5.5
# Data index :  3
# weights :  [0.1 0.  0.6]
# Data point :  [1 9 9]
# The dot product is :  5.5
# Data index :  4
# weights :  [0.1 0.  0.6]
# Data point :  [-1 -2 -1]
# The dot product is :  -0.7000000000000001
# Data index :  5
# weights :  [ 0.  -0.2  0.5]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.6000000000000002
# Data index :  6
# weights :  [-0.1 -0.4  0.3]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.3000000000000004
# Data index :  7
# weights :  [-0.2 -0.6 -0.1]
# Data point :  [-1 -7 -1]
# The dot product is :  4.500000000000001
#
#
#
# Epoch :  3
# Data index :  0
# weights :  [-0.2 -0.6 -0.1]
# Data point :  [1 1 6]
# The dot product is :  -1.3999999999999995
# Data index :  1
# weights :  [-0.1 -0.5  0.5]
# Data point :  [1 7 2]
# The dot product is :  -2.6000000000000005
# Data index :  2
# weights :  [0.  0.2 0.7]
# Data point :  [1 8 9]
# The dot product is :  7.900000000000001
# Data index :  3
# weights :  [0.  0.2 0.7]
# Data point :  [1 9 9]
# The dot product is :  8.100000000000001
# Data index :  4
# weights :  [0.  0.2 0.7]
# Data point :  [-1 -2 -1]
# The dot product is :  -1.1
# Data index :  5
# weights :  [-1.00000000e-01 -5.55111512e-17  6.00000000e-01]
# Data point :  [-1 -2 -2]
# The dot product is :  -1.1000000000000003
# Data index :  6
# weights :  [-0.2 -0.2  0.4]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.0000000000000007
# Data index :  7
# weights :  [-3.00000000e-01 -4.00000000e-01  1.66533454e-16]
# Data point :  [-1 -7 -1]
# The dot product is :  3.1000000000000005
#
#
#
# Epoch :  4
# Data index :  0
# weights :  [-3.00000000e-01 -4.00000000e-01  1.66533454e-16]
# Data point :  [1 1 6]
# The dot product is :  -0.6999999999999992
# Data index :  1
# weights :  [-0.2 -0.3  0.6]
# Data point :  [1 7 2]
# The dot product is :  -1.1
# Data index :  2
# weights :  [-0.1  0.4  0.8]
# Data point :  [1 8 9]
# The dot product is :  10.300000000000002
# Data index :  3
# weights :  [-0.1  0.4  0.8]
# Data point :  [1 9 9]
# The dot product is :  10.700000000000003
# Data index :  4
# weights :  [-0.1  0.4  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  -1.5000000000000002
# Data index :  5
# weights :  [-0.2  0.2  0.7]
# Data point :  [-1 -2 -2]
# The dot product is :  -1.6000000000000005
# Data index :  6
# weights :  [-0.3  0.   0.5]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.7000000000000008
# Data index :  7
# weights :  [-0.4 -0.2  0.1]
# Data point :  [-1 -7 -1]
# The dot product is :  1.7000000000000002
#
#
#
# Epoch :  5
# Data index :  0
# weights :  [-0.4 -0.2  0.1]
# Data point :  [1 1 6]
# The dot product is :  1.1102230246251565e-15
# Data index :  1
# weights :  [-0.4 -0.2  0.1]
# Data point :  [1 7 2]
# The dot product is :  -1.5999999999999999
# Data index :  2
# weights :  [-0.3  0.5  0.3]
# Data point :  [1 8 9]
# The dot product is :  6.400000000000002
# Data index :  3
# weights :  [-0.3  0.5  0.3]
# Data point :  [1 9 9]
# The dot product is :  6.900000000000002
# Data index :  4
# weights :  [-0.3  0.5  0.3]
# Data point :  [-1 -2 -1]
# The dot product is :  -1.0000000000000002
# Data index :  5
# weights :  [-0.4  0.3  0.2]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.6000000000000003
# Data index :  6
# weights :  [-5.00000000e-01  1.00000000e-01  1.94289029e-16]
# Data point :  [-1 -2 -4]
# The dot product is :  0.29999999999999927
# Data index :  7
# weights :  [-5.00000000e-01  1.00000000e-01  1.94289029e-16]
# Data point :  [-1 -7 -1]
# The dot product is :  -0.20000000000000004
#
#
#
# Epoch :  6
# Data index :  0
# weights :  [-0.6 -0.6 -0.1]
# Data point :  [1 1 6]
# The dot product is :  -1.799999999999999
# Data index :  1
# weights :  [-0.5 -0.5  0.5]
# Data point :  [1 7 2]
# The dot product is :  -3.0000000000000004
# Data index :  2
# weights :  [-0.4  0.2  0.7]
# Data point :  [1 8 9]
# The dot product is :  7.500000000000002
# Data index :  3
# weights :  [-0.4  0.2  0.7]
# Data point :  [1 9 9]
# The dot product is :  7.700000000000001
# Data index :  4
# weights :  [-0.4  0.2  0.7]
# Data point :  [-1 -2 -1]
# The dot product is :  -0.7000000000000001
# Data index :  5
# weights :  [-5.00000000e-01 -5.55111512e-17  6.00000000e-01]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.7000000000000003
# Data index :  6
# weights :  [-0.6 -0.2  0.4]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.6000000000000008
# Data index :  7
# weights :  [-7.00000000e-01 -4.00000000e-01  1.66533454e-16]
# Data point :  [-1 -7 -1]
# The dot product is :  3.500000000000001
#
#
#
# Epoch :  7
# Data index :  0
# weights :  [-7.00000000e-01 -4.00000000e-01  1.66533454e-16]
# Data point :  [1 1 6]
# The dot product is :  -1.0999999999999992
# Data index :  1
# weights :  [-0.6 -0.3  0.6]
# Data point :  [1 7 2]
# The dot product is :  -1.5
# Data index :  2
# weights :  [-0.5  0.4  0.8]
# Data point :  [1 8 9]
# The dot product is :  9.900000000000002
# Data index :  3
# weights :  [-0.5  0.4  0.8]
# Data point :  [1 9 9]
# The dot product is :  10.300000000000002
# Data index :  4
# weights :  [-0.5  0.4  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  -1.1000000000000003
# Data index :  5
# weights :  [-0.6  0.2  0.7]
# Data point :  [-1 -2 -2]
# The dot product is :  -1.2000000000000006
# Data index :  6
# weights :  [-0.7  0.   0.5]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.300000000000001
# Data index :  7
# weights :  [-0.8 -0.2  0.1]
# Data point :  [-1 -7 -1]
# The dot product is :  2.1
#
#
#
# Epoch :  8
# Data index :  0
# weights :  [-0.8 -0.2  0.1]
# Data point :  [1 1 6]
# The dot product is :  -0.3999999999999988
# Data index :  1
# weights :  [-0.7 -0.1  0.7]
# Data point :  [1 7 2]
# The dot product is :  6.661338147750939e-16
# Data index :  2
# weights :  [-0.7 -0.1  0.7]
# Data point :  [1 8 9]
# The dot product is :  4.8000000000000025
# Data index :  3
# weights :  [-0.7 -0.1  0.7]
# Data point :  [1 9 9]
# The dot product is :  4.700000000000003
# Data index :  4
# weights :  [-0.7 -0.1  0.7]
# Data point :  [-1 -2 -1]
# The dot product is :  0.19999999999999962
# Data index :  5
# weights :  [-0.7 -0.1  0.7]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.5000000000000007
# Data index :  6
# weights :  [-0.8 -0.3  0.5]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.600000000000001
# Data index :  7
# weights :  [-0.9 -0.5  0.1]
# Data point :  [-1 -7 -1]
# The dot product is :  4.3
#
#
#
# Epoch :  9
# Data index :  0
# weights :  [-0.9 -0.5  0.1]
# Data point :  [1 1 6]
# The dot product is :  -0.7999999999999987
# Data index :  1
# weights :  [-0.8 -0.4  0.7]
# Data point :  [1 7 2]
# The dot product is :  -2.1999999999999993
# Data index :  2
# weights :  [-0.7  0.3  0.9]
# Data point :  [1 8 9]
# The dot product is :  9.800000000000004
# Data index :  3
# weights :  [-0.7  0.3  0.9]
# Data point :  [1 9 9]
# The dot product is :  10.100000000000003
# Data index :  4
# weights :  [-0.7  0.3  0.9]
# Data point :  [-1 -2 -1]
# The dot product is :  -0.8000000000000005
# Data index :  5
# weights :  [-0.8  0.1  0.8]
# Data point :  [-1 -2 -2]
# The dot product is :  -1.0000000000000009
# Data index :  6
# weights :  [-0.9 -0.1  0.6]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.3000000000000014
# Data index :  7
# weights :  [-1.  -0.3  0.2]
# Data point :  [-1 -7 -1]
# The dot product is :  2.9
#
#
#
# Epoch :  10
# Data index :  0
# weights :  [-1.  -0.3  0.2]
# Data point :  [1 1 6]
# The dot product is :  -0.09999999999999809
# Data index :  1
# weights :  [-0.9 -0.2  0.8]
# Data point :  [1 7 2]
# The dot product is :  -0.6999999999999991
# Data index :  2
# weights :  [-0.8  0.5  1. ]
# Data point :  [1 8 9]
# The dot product is :  12.200000000000005
# Data index :  3
# weights :  [-0.8  0.5  1. ]
# Data point :  [1 9 9]
# The dot product is :  12.700000000000005
# Data index :  4
# weights :  [-0.8  0.5  1. ]
# Data point :  [-1 -2 -1]
# The dot product is :  -1.2000000000000006
# Data index :  5
# weights :  [-0.9  0.3  0.9]
# Data point :  [-1 -2 -2]
# The dot product is :  -1.5000000000000013
# Data index :  6
# weights :  [-1.   0.1  0.7]
# Data point :  [-1 -2 -4]
# The dot product is :  -2.0000000000000018
# Data index :  7
# weights :  [-1.1 -0.1  0.3]
# Data point :  [-1 -7 -1]
# The dot product is :  1.4999999999999991
#
#
#
# Epoch :  11
# Data index :  0
# weights :  [-1.1 -0.1  0.3]
# Data point :  [1 1 6]
# The dot product is :  0.6000000000000025
# Data index :  1
# weights :  [-1.1 -0.1  0.3]
# Data point :  [1 7 2]
# The dot product is :  -1.1999999999999986
# Data index :  2
# weights :  [-1.   0.6  0.5]
# Data point :  [1 8 9]
# The dot product is :  8.300000000000004
# Data index :  3
# weights :  [-1.   0.6  0.5]
# Data point :  [1 9 9]
# The dot product is :  8.900000000000004
# Data index :  4
# weights :  [-1.   0.6  0.5]
# Data point :  [-1 -2 -1]
# The dot product is :  -0.7000000000000007
# Data index :  5
# weights :  [-1.1  0.4  0.4]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.5000000000000012
# Data index :  6
# weights :  [-1.2  0.2  0.2]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.9984014443252818e-15
# Data index :  7
# weights :  [-1.30000000e+00  5.55111512e-17 -2.00000000e-01]
# Data point :  [-1 -7 -1]
# The dot product is :  1.4999999999999991
#
#
#
# Epoch :  12
# Data index :  0
# weights :  [-1.30000000e+00  5.55111512e-17 -2.00000000e-01]
# Data point :  [1 1 6]
# The dot product is :  -2.4999999999999973
# Data index :  1
# weights :  [-1.2  0.1  0.4]
# Data point :  [1 7 2]
# The dot product is :  0.3000000000000015
# Data index :  2
# weights :  [-1.2  0.1  0.4]
# Data point :  [1 8 9]
# The dot product is :  3.200000000000005
# Data index :  3
# weights :  [-1.2  0.1  0.4]
# Data point :  [1 9 9]
# The dot product is :  3.300000000000005
# Data index :  4
# weights :  [-1.2  0.1  0.4]
# Data point :  [-1 -2 -1]
# The dot product is :  0.5999999999999992
# Data index :  5
# weights :  [-1.2  0.1  0.4]
# Data point :  [-1 -2 -2]
# The dot product is :  0.19999999999999873
# Data index :  6
# weights :  [-1.2  0.1  0.4]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.6000000000000023
# Data index :  7
# weights :  [-1.30000000e+00 -1.00000000e-01  4.99600361e-16]
# Data point :  [-1 -7 -1]
# The dot product is :  1.9999999999999991
#
#
#
# Epoch :  13
# Data index :  0
# weights :  [-1.30000000e+00 -1.00000000e-01  4.99600361e-16]
# Data point :  [1 1 6]
# The dot product is :  -1.3999999999999968
# Data index :  1
# weights :  [-1.20000000e+00  5.55111512e-17  6.00000000e-01]
# Data point :  [1 7 2]
# The dot product is :  1.5543122344752192e-15
# Data index :  2
# weights :  [-1.20000000e+00  5.55111512e-17  6.00000000e-01]
# Data point :  [1 8 9]
# The dot product is :  4.2000000000000055
# Data index :  3
# weights :  [-1.20000000e+00  5.55111512e-17  6.00000000e-01]
# Data point :  [1 9 9]
# The dot product is :  4.2000000000000055
# Data index :  4
# weights :  [-1.20000000e+00  5.55111512e-17  6.00000000e-01]
# Data point :  [-1 -2 -1]
# The dot product is :  0.5999999999999992
# Data index :  5
# weights :  [-1.20000000e+00  5.55111512e-17  6.00000000e-01]
# Data point :  [-1 -2 -2]
# The dot product is :  -1.3322676295501878e-15
# Data index :  6
# weights :  [-1.3 -0.2  0.4]
# Data point :  [-1 -2 -4]
# The dot product is :  0.09999999999999787
# Data index :  7
# weights :  [-1.3 -0.2  0.4]
# Data point :  [-1 -7 -1]
# The dot product is :  2.2999999999999994
#
#
#
# Epoch :  14
# Data index :  0
# weights :  [-1.3 -0.2  0.4]
# Data point :  [1 1 6]
# The dot product is :  0.900000000000003
# Data index :  1
# weights :  [-1.3 -0.2  0.4]
# Data point :  [1 7 2]
# The dot product is :  -1.8999999999999986
# Data index :  2
# weights :  [-1.2  0.5  0.6]
# Data point :  [1 8 9]
# The dot product is :  8.200000000000006
# Data index :  3
# weights :  [-1.2  0.5  0.6]
# Data point :  [1 9 9]
# The dot product is :  8.700000000000006
# Data index :  4
# weights :  [-1.2  0.5  0.6]
# Data point :  [-1 -2 -1]
# The dot product is :  -0.4000000000000008
# Data index :  5
# weights :  [-1.3  0.3  0.5]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.30000000000000127
# Data index :  6
# weights :  [-1.4  0.1  0.3]
# Data point :  [-1 -2 -4]
# The dot product is :  -2.220446049250313e-15
# Data index :  7
# weights :  [-1.5 -0.1 -0.1]
# Data point :  [-1 -7 -1]
# The dot product is :  2.2999999999999994
#
#
#
# Epoch :  15
# Data index :  0
# weights :  [-1.5 -0.1 -0.1]
# Data point :  [1 1 6]
# The dot product is :  -2.199999999999997
# Data index :  1
# weights :  [-1.40000000e+00  8.32667268e-17  5.00000000e-01]
# Data point :  [1 7 2]
# The dot product is :  -0.39999999999999813
# Data index :  2
# weights :  [-1.3  0.7  0.7]
# Data point :  [1 8 9]
# The dot product is :  10.600000000000009
# Data index :  3
# weights :  [-1.3  0.7  0.7]
# Data point :  [1 9 9]
# The dot product is :  11.300000000000008
# Data index :  4
# weights :  [-1.3  0.7  0.7]
# Data point :  [-1 -2 -1]
# The dot product is :  -0.8000000000000009
# Data index :  5
# weights :  [-1.4  0.5  0.6]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.8000000000000016
# Data index :  6
# weights :  [-1.5  0.3  0.4]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.7000000000000027
# Data index :  7
# weights :  [-1.60000000e+00  1.00000000e-01  6.10622664e-16]
# Data point :  [-1 -7 -1]
# The dot product is :  0.8999999999999984
#
#
#
# Epoch :  16
# Data index :  0
# weights :  [-1.60000000e+00  1.00000000e-01  6.10622664e-16]
# Data point :  [1 1 6]
# The dot product is :  -1.4999999999999964
# Data index :  1
# weights :  [-1.5  0.2  0.6]
# Data point :  [1 7 2]
# The dot product is :  1.1000000000000028
# Data index :  2
# weights :  [-1.5  0.2  0.6]
# Data point :  [1 8 9]
# The dot product is :  5.500000000000008
# Data index :  3
# weights :  [-1.5  0.2  0.6]
# Data point :  [1 9 9]
# The dot product is :  5.700000000000008
# Data index :  4
# weights :  [-1.5  0.2  0.6]
# Data point :  [-1 -2 -1]
# The dot product is :  0.4999999999999991
# Data index :  5
# weights :  [-1.5  0.2  0.6]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.10000000000000164
# Data index :  6
# weights :  [-1.60000000e+00  1.94289029e-16  4.00000000e-01]
# Data point :  [-1 -2 -4]
# The dot product is :  -3.1086244689504383e-15
# Data index :  7
# weights :  [-1.70000000e+00 -2.00000000e-01  7.21644966e-16]
# Data point :  [-1 -7 -1]
# The dot product is :  3.0999999999999983
#
#
#
# Epoch :  17
# Data index :  0
# weights :  [-1.70000000e+00 -2.00000000e-01  7.21644966e-16]
# Data point :  [1 1 6]
# The dot product is :  -1.899999999999996
# Data index :  1
# weights :  [-1.6 -0.1  0.6]
# Data point :  [1 7 2]
# The dot product is :  -1.0999999999999974
# Data index :  2
# weights :  [-1.5  0.6  0.8]
# Data point :  [1 8 9]
# The dot product is :  10.500000000000009
# Data index :  3
# weights :  [-1.5  0.6  0.8]
# Data point :  [1 9 9]
# The dot product is :  11.100000000000009
# Data index :  4
# weights :  [-1.5  0.6  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  -0.5000000000000011
# Data index :  5
# weights :  [-1.6  0.4  0.7]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.6000000000000018
# Data index :  6
# weights :  [-1.7  0.2  0.5]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.7000000000000028
# Data index :  7
# weights :  [-1.80000000e+00  2.77555756e-16  1.00000000e-01]
# Data point :  [-1 -7 -1]
# The dot product is :  1.699999999999998
#
#
#
# Epoch :  18
# Data index :  0
# weights :  [-1.80000000e+00  2.77555756e-16  1.00000000e-01]
# Data point :  [1 1 6]
# The dot product is :  -1.1999999999999964
# Data index :  1
# weights :  [-1.7  0.1  0.7]
# Data point :  [1 7 2]
# The dot product is :  0.400000000000003
# Data index :  2
# weights :  [-1.7  0.1  0.7]
# Data point :  [1 8 9]
# The dot product is :  5.400000000000009
# Data index :  3
# weights :  [-1.7  0.1  0.7]
# Data point :  [1 9 9]
# The dot product is :  5.500000000000009
# Data index :  4
# weights :  [-1.7  0.1  0.7]
# Data point :  [-1 -2 -1]
# The dot product is :  0.799999999999999
# Data index :  5
# weights :  [-1.7  0.1  0.7]
# Data point :  [-1 -2 -2]
# The dot product is :  0.09999999999999831
# Data index :  6
# weights :  [-1.7  0.1  0.7]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.3000000000000032
# Data index :  7
# weights :  [-1.8 -0.1  0.3]
# Data point :  [-1 -7 -1]
# The dot product is :  2.199999999999998
#
#
#
# Epoch :  19
# Data index :  0
# weights :  [-1.8 -0.1  0.3]
# Data point :  [1 1 6]
# The dot product is :  -0.09999999999999587
# Data index :  1
# weights :  [-1.70000000e+00  2.77555756e-16  9.00000000e-01]
# Data point :  [1 7 2]
# The dot product is :  0.1000000000000032
# Data index :  2
# weights :  [-1.70000000e+00  2.77555756e-16  9.00000000e-01]
# Data point :  [1 8 9]
# The dot product is :  6.400000000000008
# Data index :  3
# weights :  [-1.70000000e+00  2.77555756e-16  9.00000000e-01]
# Data point :  [1 9 9]
# The dot product is :  6.400000000000009
# Data index :  4
# weights :  [-1.70000000e+00  2.77555756e-16  9.00000000e-01]
# Data point :  [-1 -2 -1]
# The dot product is :  0.7999999999999989
# Data index :  5
# weights :  [-1.70000000e+00  2.77555756e-16  9.00000000e-01]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.10000000000000187
# Data index :  6
# weights :  [-1.8 -0.2  0.7]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.6000000000000032
# Data index :  7
# weights :  [-1.9 -0.4  0.3]
# Data point :  [-1 -7 -1]
# The dot product is :  4.399999999999998
#
#
#
# Epoch :  20
# Data index :  0
# weights :  [-1.9 -0.4  0.3]
# Data point :  [1 1 6]
# The dot product is :  -0.49999999999999534
# Data index :  1
# weights :  [-1.8 -0.3  0.9]
# Data point :  [1 7 2]
# The dot product is :  -2.099999999999997
# Data index :  2
# weights :  [-1.7  0.4  1.1]
# Data point :  [1 8 9]
# The dot product is :  11.400000000000011
# Data index :  3
# weights :  [-1.7  0.4  1.1]
# Data point :  [1 9 9]
# The dot product is :  11.800000000000011
# Data index :  4
# weights :  [-1.7  0.4  1.1]
# Data point :  [-1 -2 -1]
# The dot product is :  -0.2000000000000013
# Data index :  5
# weights :  [-1.8  0.2  1. ]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.6000000000000019
# Data index :  6
# weights :  [-1.90000000e+00  3.33066907e-16  8.00000000e-01]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.3000000000000038
# Data index :  7
# weights :  [-2.  -0.2  0.4]
# Data point :  [-1 -7 -1]
# The dot product is :  2.9999999999999973
#
#
#
# Epoch :  21
# Data index :  0
# weights :  [-2.  -0.2  0.4]
# Data point :  [1 1 6]
# The dot product is :  0.2000000000000055
# Data index :  1
# weights :  [-2.  -0.2  0.4]
# Data point :  [1 7 2]
# The dot product is :  -2.599999999999996
# Data index :  2
# weights :  [-1.9  0.5  0.6]
# Data point :  [1 8 9]
# The dot product is :  7.500000000000012
# Data index :  3
# weights :  [-1.9  0.5  0.6]
# Data point :  [1 9 9]
# The dot product is :  8.000000000000012
# Data index :  4
# weights :  [-1.9  0.5  0.6]
# Data point :  [-1 -2 -1]
# The dot product is :  0.2999999999999985
# Data index :  5
# weights :  [-1.9  0.5  0.6]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.3000000000000025
# Data index :  6
# weights :  [-2.   0.3  0.4]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.2000000000000044
# Data index :  7
# weights :  [-2.10000000e+00  1.00000000e-01  9.43689571e-16]
# Data point :  [-1 -7 -1]
# The dot product is :  1.3999999999999968
#
#
#
# Epoch :  22
# Data index :  0
# weights :  [-2.10000000e+00  1.00000000e-01  9.43689571e-16]
# Data point :  [1 1 6]
# The dot product is :  -1.9999999999999942
# Data index :  1
# weights :  [-2.   0.2  0.6]
# Data point :  [1 7 2]
# The dot product is :  0.6000000000000045
# Data index :  2
# weights :  [-2.   0.2  0.6]
# Data point :  [1 8 9]
# The dot product is :  5.000000000000012
# Data index :  3
# weights :  [-2.   0.2  0.6]
# Data point :  [1 9 9]
# The dot product is :  5.200000000000013
# Data index :  4
# weights :  [-2.   0.2  0.6]
# Data point :  [-1 -2 -1]
# The dot product is :  0.9999999999999987
# Data index :  5
# weights :  [-2.   0.2  0.6]
# Data point :  [-1 -2 -2]
# The dot product is :  0.3999999999999977
# Data index :  6
# weights :  [-2.   0.2  0.6]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.8000000000000043
# Data index :  7
# weights :  [-2.10000000e+00  4.16333634e-16  2.00000000e-01]
# Data point :  [-1 -7 -1]
# The dot product is :  1.8999999999999964
#
#
#
# Epoch :  23
# Data index :  0
# weights :  [-2.10000000e+00  4.16333634e-16  2.00000000e-01]
# Data point :  [1 1 6]
# The dot product is :  -0.8999999999999944
# Data index :  1
# weights :  [-2.   0.1  0.8]
# Data point :  [1 7 2]
# The dot product is :  0.3000000000000045
# Data index :  2
# weights :  [-2.   0.1  0.8]
# Data point :  [1 8 9]
# The dot product is :  6.000000000000012
# Data index :  3
# weights :  [-2.   0.1  0.8]
# Data point :  [1 9 9]
# The dot product is :  6.100000000000012
# Data index :  4
# weights :  [-2.   0.1  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  0.9999999999999986
# Data index :  5
# weights :  [-2.   0.1  0.8]
# Data point :  [-1 -2 -2]
# The dot product is :  0.1999999999999975
# Data index :  6
# weights :  [-2.   0.1  0.8]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.4000000000000046
# Data index :  7
# weights :  [-2.1 -0.1  0.4]
# Data point :  [-1 -7 -1]
# The dot product is :  2.399999999999997
#
#
#
# Epoch :  24
# Data index :  0
# weights :  [-2.1 -0.1  0.4]
# Data point :  [1 1 6]
# The dot product is :  0.20000000000000595
# Data index :  1
# weights :  [-2.1 -0.1  0.4]
# Data point :  [1 7 2]
# The dot product is :  -1.9999999999999956
# Data index :  2
# weights :  [-2.   0.6  0.6]
# Data point :  [1 8 9]
# The dot product is :  8.200000000000014
# Data index :  3
# weights :  [-2.   0.6  0.6]
# Data point :  [1 9 9]
# The dot product is :  8.800000000000013
# Data index :  4
# weights :  [-2.   0.6  0.6]
# Data point :  [-1 -2 -1]
# The dot product is :  0.1999999999999984
# Data index :  5
# weights :  [-2.   0.6  0.6]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.4000000000000026
# Data index :  6
# weights :  [-2.1  0.4  0.4]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.3000000000000045
# Data index :  7
# weights :  [-2.20000000e+00  2.00000000e-01  9.43689571e-16]
# Data point :  [-1 -7 -1]
# The dot product is :  0.7999999999999963
#
#
#
# Epoch :  25
# Data index :  0
# weights :  [-2.20000000e+00  2.00000000e-01  9.43689571e-16]
# Data point :  [1 1 6]
# The dot product is :  -1.9999999999999942
# Data index :  1
# weights :  [-2.1  0.3  0.6]
# Data point :  [1 7 2]
# The dot product is :  1.2000000000000046
# Data index :  2
# weights :  [-2.1  0.3  0.6]
# Data point :  [1 8 9]
# The dot product is :  5.700000000000013
# Data index :  3
# weights :  [-2.1  0.3  0.6]
# Data point :  [1 9 9]
# The dot product is :  6.000000000000013
# Data index :  4
# weights :  [-2.1  0.3  0.6]
# Data point :  [-1 -2 -1]
# The dot product is :  0.8999999999999986
# Data index :  5
# weights :  [-2.1  0.3  0.6]
# Data point :  [-1 -2 -2]
# The dot product is :  0.2999999999999976
# Data index :  6
# weights :  [-2.1  0.3  0.6]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.9000000000000044
# Data index :  7
# weights :  [-2.2  0.1  0.2]
# Data point :  [-1 -7 -1]
# The dot product is :  1.2999999999999963
#
#
#
# Epoch :  26
# Data index :  0
# weights :  [-2.2  0.1  0.2]
# Data point :  [1 1 6]
# The dot product is :  -0.8999999999999944
# Data index :  1
# weights :  [-2.1  0.2  0.8]
# Data point :  [1 7 2]
# The dot product is :  0.900000000000005
# Data index :  2
# weights :  [-2.1  0.2  0.8]
# Data point :  [1 8 9]
# The dot product is :  6.700000000000013
# Data index :  3
# weights :  [-2.1  0.2  0.8]
# Data point :  [1 9 9]
# The dot product is :  6.900000000000013
# Data index :  4
# weights :  [-2.1  0.2  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  0.8999999999999985
# Data index :  5
# weights :  [-2.1  0.2  0.8]
# Data point :  [-1 -2 -2]
# The dot product is :  0.09999999999999742
# Data index :  6
# weights :  [-2.1  0.2  0.8]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.5000000000000047
# Data index :  7
# weights :  [-2.20000000e+00  4.71844785e-16  4.00000000e-01]
# Data point :  [-1 -7 -1]
# The dot product is :  1.7999999999999965
#
#
#
# Epoch :  27
# Data index :  0
# weights :  [-2.20000000e+00  4.71844785e-16  4.00000000e-01]
# Data point :  [1 1 6]
# The dot product is :  0.20000000000000595
# Data index :  1
# weights :  [-2.20000000e+00  4.71844785e-16  4.00000000e-01]
# Data point :  [1 7 2]
# The dot product is :  -1.3999999999999955
# Data index :  2
# weights :  [-2.1  0.7  0.6]
# Data point :  [1 8 9]
# The dot product is :  8.900000000000013
# Data index :  3
# weights :  [-2.1  0.7  0.6]
# Data point :  [1 9 9]
# The dot product is :  9.600000000000012
# Data index :  4
# weights :  [-2.1  0.7  0.6]
# Data point :  [-1 -2 -1]
# The dot product is :  0.09999999999999853
# Data index :  5
# weights :  [-2.1  0.7  0.6]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.5000000000000024
# Data index :  6
# weights :  [-2.2  0.5  0.4]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.40000000000000413
# Data index :  7
# weights :  [-2.30000000e+00  3.00000000e-01  9.43689571e-16]
# Data point :  [-1 -7 -1]
# The dot product is :  0.19999999999999657
#
#
#
# Epoch :  28
# Data index :  0
# weights :  [-2.30000000e+00  3.00000000e-01  9.43689571e-16]
# Data point :  [1 1 6]
# The dot product is :  -1.9999999999999947
# Data index :  1
# weights :  [-2.2  0.4  0.6]
# Data point :  [1 7 2]
# The dot product is :  1.8000000000000047
# Data index :  2
# weights :  [-2.2  0.4  0.6]
# Data point :  [1 8 9]
# The dot product is :  6.400000000000013
# Data index :  3
# weights :  [-2.2  0.4  0.6]
# Data point :  [1 9 9]
# The dot product is :  6.800000000000013
# Data index :  4
# weights :  [-2.2  0.4  0.6]
# Data point :  [-1 -2 -1]
# The dot product is :  0.7999999999999987
# Data index :  5
# weights :  [-2.2  0.4  0.6]
# Data point :  [-1 -2 -2]
# The dot product is :  0.19999999999999774
# Data index :  6
# weights :  [-2.2  0.4  0.6]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.0000000000000042
# Data index :  7
# weights :  [-2.3  0.2  0.2]
# Data point :  [-1 -7 -1]
# The dot product is :  0.6999999999999965
#
#
#
# Epoch :  29
# Data index :  0
# weights :  [-2.3  0.2  0.2]
# Data point :  [1 1 6]
# The dot product is :  -0.8999999999999944
# Data index :  1
# weights :  [-2.2  0.3  0.8]
# Data point :  [1 7 2]
# The dot product is :  1.5000000000000047
# Data index :  2
# weights :  [-2.2  0.3  0.8]
# Data point :  [1 8 9]
# The dot product is :  7.400000000000013
# Data index :  3
# weights :  [-2.2  0.3  0.8]
# Data point :  [1 9 9]
# The dot product is :  7.7000000000000135
# Data index :  4
# weights :  [-2.2  0.3  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  0.7999999999999986
# Data index :  5
# weights :  [-2.2  0.3  0.8]
# Data point :  [-1 -2 -2]
# The dot product is :  -2.4424906541753444e-15
# Data index :  6
# weights :  [-2.3  0.1  0.6]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.30000000000000426
# Data index :  7
# weights :  [-2.4 -0.1  0.2]
# Data point :  [-1 -7 -1]
# The dot product is :  2.8999999999999964
#
#
#
# Epoch :  30
# Data index :  0
# weights :  [-2.4 -0.1  0.2]
# Data point :  [1 1 6]
# The dot product is :  -1.2999999999999947
# Data index :  1
# weights :  [-2.30000000e+00  4.71844785e-16  8.00000000e-01]
# Data point :  [1 7 2]
# The dot product is :  -0.6999999999999955
# Data index :  2
# weights :  [-2.2  0.7  1. ]
# Data point :  [1 8 9]
# The dot product is :  12.400000000000015
# Data index :  3
# weights :  [-2.2  0.7  1. ]
# Data point :  [1 9 9]
# The dot product is :  13.100000000000014
# Data index :  4
# weights :  [-2.2  0.7  1. ]
# Data point :  [-1 -2 -1]
# The dot product is :  -0.2000000000000015
# Data index :  5
# weights :  [-2.3  0.5  0.9]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.5000000000000024
# Data index :  6
# weights :  [-2.4  0.3  0.7]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.0000000000000044
# Data index :  7
# weights :  [-2.5  0.1  0.3]
# Data point :  [-1 -7 -1]
# The dot product is :  1.499999999999997
#
#
#
# Epoch :  31
# Data index :  0
# weights :  [-2.5  0.1  0.3]
# Data point :  [1 1 6]
# The dot product is :  -0.5999999999999941
# Data index :  1
# weights :  [-2.4  0.2  0.9]
# Data point :  [1 7 2]
# The dot product is :  0.8000000000000045
# Data index :  2
# weights :  [-2.4  0.2  0.9]
# Data point :  [1 8 9]
# The dot product is :  7.300000000000013
# Data index :  3
# weights :  [-2.4  0.2  0.9]
# Data point :  [1 9 9]
# The dot product is :  7.500000000000013
# Data index :  4
# weights :  [-2.4  0.2  0.9]
# Data point :  [-1 -2 -1]
# The dot product is :  1.0999999999999988
# Data index :  5
# weights :  [-2.4  0.2  0.9]
# Data point :  [-1 -2 -2]
# The dot product is :  0.19999999999999774
# Data index :  6
# weights :  [-2.4  0.2  0.9]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.6000000000000045
# Data index :  7
# weights :  [-2.50000000e+00  4.16333634e-16  5.00000000e-01]
# Data point :  [-1 -7 -1]
# The dot product is :  1.9999999999999967
#
#
#
# Epoch :  32
# Data index :  0
# weights :  [-2.50000000e+00  4.16333634e-16  5.00000000e-01]
# Data point :  [1 1 6]
# The dot product is :  0.5000000000000062
# Data index :  1
# weights :  [-2.50000000e+00  4.16333634e-16  5.00000000e-01]
# Data point :  [1 7 2]
# The dot product is :  -1.4999999999999956
# Data index :  2
# weights :  [-2.4  0.7  0.7]
# Data point :  [1 8 9]
# The dot product is :  9.500000000000012
# Data index :  3
# weights :  [-2.4  0.7  0.7]
# Data point :  [1 9 9]
# The dot product is :  10.200000000000014
# Data index :  4
# weights :  [-2.4  0.7  0.7]
# Data point :  [-1 -2 -1]
# The dot product is :  0.2999999999999987
# Data index :  5
# weights :  [-2.4  0.7  0.7]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.40000000000000235
# Data index :  6
# weights :  [-2.5  0.5  0.5]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.5000000000000044
# Data index :  7
# weights :  [-2.6  0.3  0.1]
# Data point :  [-1 -7 -1]
# The dot product is :  0.3999999999999967
#
#
#
# Epoch :  33
# Data index :  0
# weights :  [-2.6  0.3  0.1]
# Data point :  [1 1 6]
# The dot product is :  -1.6999999999999942
# Data index :  1
# weights :  [-2.5  0.4  0.7]
# Data point :  [1 7 2]
# The dot product is :  1.7000000000000048
# Data index :  2
# weights :  [-2.5  0.4  0.7]
# Data point :  [1 8 9]
# The dot product is :  7.000000000000013
# Data index :  3
# weights :  [-2.5  0.4  0.7]
# Data point :  [1 9 9]
# The dot product is :  7.400000000000014
# Data index :  4
# weights :  [-2.5  0.4  0.7]
# Data point :  [-1 -2 -1]
# The dot product is :  0.9999999999999988
# Data index :  5
# weights :  [-2.5  0.4  0.7]
# Data point :  [-1 -2 -2]
# The dot product is :  0.2999999999999976
# Data index :  6
# weights :  [-2.5  0.4  0.7]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.1000000000000048
# Data index :  7
# weights :  [-2.6  0.2  0.3]
# Data point :  [-1 -7 -1]
# The dot product is :  0.8999999999999966
#
#
#
# Epoch :  34
# Data index :  0
# weights :  [-2.6  0.2  0.3]
# Data point :  [1 1 6]
# The dot product is :  -0.5999999999999934
# Data index :  1
# weights :  [-2.5  0.3  0.9]
# Data point :  [1 7 2]
# The dot product is :  1.4000000000000048
# Data index :  2
# weights :  [-2.5  0.3  0.9]
# Data point :  [1 8 9]
# The dot product is :  8.000000000000014
# Data index :  3
# weights :  [-2.5  0.3  0.9]
# Data point :  [1 9 9]
# The dot product is :  8.300000000000015
# Data index :  4
# weights :  [-2.5  0.3  0.9]
# Data point :  [-1 -2 -1]
# The dot product is :  0.9999999999999987
# Data index :  5
# weights :  [-2.5  0.3  0.9]
# Data point :  [-1 -2 -2]
# The dot product is :  0.09999999999999742
# Data index :  6
# weights :  [-2.5  0.3  0.9]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.700000000000005
# Data index :  7
# weights :  [-2.6  0.1  0.5]
# Data point :  [-1 -7 -1]
# The dot product is :  1.3999999999999964
#
#
#
# Epoch :  35
# Data index :  0
# weights :  [-2.6  0.1  0.5]
# Data point :  [1 1 6]
# The dot product is :  0.5000000000000067
# Data index :  1
# weights :  [-2.6  0.1  0.5]
# Data point :  [1 7 2]
# The dot product is :  -0.8999999999999952
# Data index :  2
# weights :  [-2.5  0.8  0.7]
# Data point :  [1 8 9]
# The dot product is :  10.200000000000014
# Data index :  3
# weights :  [-2.5  0.8  0.7]
# Data point :  [1 9 9]
# The dot product is :  11.000000000000014
# Data index :  4
# weights :  [-2.5  0.8  0.7]
# Data point :  [-1 -2 -1]
# The dot product is :  0.19999999999999862
# Data index :  5
# weights :  [-2.5  0.8  0.7]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.5000000000000027
# Data index :  6
# weights :  [-2.6  0.6  0.5]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.6000000000000054
# Data index :  7
# weights :  [-2.7  0.4  0.1]
# Data point :  [-1 -7 -1]
# The dot product is :  -0.20000000000000406
#
#
#
# Epoch :  36
# Data index :  0
# weights :  [-2.80000000e+00 -3.00000000e-01  1.30451205e-15]
# Data point :  [1 1 6]
# The dot product is :  -3.0999999999999925
# Data index :  1
# weights :  [-2.7 -0.2  0.6]
# Data point :  [1 7 2]
# The dot product is :  -2.899999999999995
# Data index :  2
# weights :  [-2.6  0.5  0.8]
# Data point :  [1 8 9]
# The dot product is :  8.600000000000016
# Data index :  3
# weights :  [-2.6  0.5  0.8]
# Data point :  [1 9 9]
# The dot product is :  9.100000000000017
# Data index :  4
# weights :  [-2.6  0.5  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  0.7999999999999985
# Data index :  5
# weights :  [-2.6  0.5  0.8]
# Data point :  [-1 -2 -2]
# The dot product is :  -2.886579864025407e-15
# Data index :  6
# weights :  [-2.7  0.3  0.6]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.3000000000000056
# Data index :  7
# weights :  [-2.8  0.1  0.2]
# Data point :  [-1 -7 -1]
# The dot product is :  1.899999999999996
#
#
#
# Epoch :  37
# Data index :  0
# weights :  [-2.8  0.1  0.2]
# Data point :  [1 1 6]
# The dot product is :  -1.4999999999999922
# Data index :  1
# weights :  [-2.7  0.2  0.8]
# Data point :  [1 7 2]
# The dot product is :  0.3000000000000056
# Data index :  2
# weights :  [-2.7  0.2  0.8]
# Data point :  [1 8 9]
# The dot product is :  6.1000000000000165
# Data index :  3
# weights :  [-2.7  0.2  0.8]
# Data point :  [1 9 9]
# The dot product is :  6.300000000000018
# Data index :  4
# weights :  [-2.7  0.2  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  1.4999999999999982
# Data index :  5
# weights :  [-2.7  0.2  0.8]
# Data point :  [-1 -2 -2]
# The dot product is :  0.6999999999999968
# Data index :  6
# weights :  [-2.7  0.2  0.8]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.9000000000000061
# Data index :  7
# weights :  [-2.80000000e+00  5.27355937e-16  4.00000000e-01]
# Data point :  [-1 -7 -1]
# The dot product is :  2.399999999999996
#
#
#
# Epoch :  38
# Data index :  0
# weights :  [-2.80000000e+00  5.27355937e-16  4.00000000e-01]
# Data point :  [1 1 6]
# The dot product is :  -0.3999999999999919
# Data index :  1
# weights :  [-2.7  0.1  1. ]
# Data point :  [1 7 2]
# The dot product is :  5.773159728050814e-15
# Data index :  2
# weights :  [-2.7  0.1  1. ]
# Data point :  [1 8 9]
# The dot product is :  7.100000000000017
# Data index :  3
# weights :  [-2.7  0.1  1. ]
# Data point :  [1 9 9]
# The dot product is :  7.200000000000018
# Data index :  4
# weights :  [-2.7  0.1  1. ]
# Data point :  [-1 -2 -1]
# The dot product is :  1.4999999999999984
# Data index :  5
# weights :  [-2.7  0.1  1. ]
# Data point :  [-1 -2 -2]
# The dot product is :  0.4999999999999969
# Data index :  6
# weights :  [-2.7  0.1  1. ]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.5000000000000062
# Data index :  7
# weights :  [-2.8 -0.1  0.6]
# Data point :  [-1 -7 -1]
# The dot product is :  2.899999999999996
#
#
#
# Epoch :  39
# Data index :  0
# weights :  [-2.8 -0.1  0.6]
# Data point :  [1 1 6]
# The dot product is :  0.7000000000000086
# Data index :  1
# weights :  [-2.8 -0.1  0.6]
# Data point :  [1 7 2]
# The dot product is :  -2.2999999999999945
# Data index :  2
# weights :  [-2.7  0.6  0.8]
# Data point :  [1 8 9]
# The dot product is :  9.300000000000018
# Data index :  3
# weights :  [-2.7  0.6  0.8]
# Data point :  [1 9 9]
# The dot product is :  9.900000000000018
# Data index :  4
# weights :  [-2.7  0.6  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  0.6999999999999984
# Data index :  5
# weights :  [-2.7  0.6  0.8]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.1000000000000032
# Data index :  6
# weights :  [-2.8  0.4  0.6]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.4000000000000066
# Data index :  7
# weights :  [-2.9  0.2  0.2]
# Data point :  [-1 -7 -1]
# The dot product is :  1.2999999999999963
#
#
#
# Epoch :  40
# Data index :  0
# weights :  [-2.9  0.2  0.2]
# Data point :  [1 1 6]
# The dot product is :  -1.499999999999991
# Data index :  1
# weights :  [-2.8  0.3  0.8]
# Data point :  [1 7 2]
# The dot product is :  0.9000000000000055
# Data index :  2
# weights :  [-2.8  0.3  0.8]
# Data point :  [1 8 9]
# The dot product is :  6.8000000000000185
# Data index :  3
# weights :  [-2.8  0.3  0.8]
# Data point :  [1 9 9]
# The dot product is :  7.100000000000019
# Data index :  4
# weights :  [-2.8  0.3  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  1.3999999999999986
# Data index :  5
# weights :  [-2.8  0.3  0.8]
# Data point :  [-1 -2 -2]
# The dot product is :  0.5999999999999968
# Data index :  6
# weights :  [-2.8  0.3  0.8]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.0000000000000067
# Data index :  7
# weights :  [-2.9  0.1  0.4]
# Data point :  [-1 -7 -1]
# The dot product is :  1.7999999999999963
#
#
#
# Epoch :  41
# Data index :  0
# weights :  [-2.9  0.1  0.4]
# Data point :  [1 1 6]
# The dot product is :  -0.3999999999999906
# Data index :  1
# weights :  [-2.8  0.2  1. ]
# Data point :  [1 7 2]
# The dot product is :  0.6000000000000059
# Data index :  2
# weights :  [-2.8  0.2  1. ]
# Data point :  [1 8 9]
# The dot product is :  7.8000000000000185
# Data index :  3
# weights :  [-2.8  0.2  1. ]
# Data point :  [1 9 9]
# The dot product is :  8.00000000000002
# Data index :  4
# weights :  [-2.8  0.2  1. ]
# Data point :  [-1 -2 -1]
# The dot product is :  1.3999999999999986
# Data index :  5
# weights :  [-2.8  0.2  1. ]
# Data point :  [-1 -2 -2]
# The dot product is :  0.3999999999999968
# Data index :  6
# weights :  [-2.8  0.2  1. ]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.6000000000000068
# Data index :  7
# weights :  [-2.90000000e+00  4.71844785e-16  6.00000000e-01]
# Data point :  [-1 -7 -1]
# The dot product is :  2.2999999999999963
#
#
#
# Epoch :  42
# Data index :  0
# weights :  [-2.90000000e+00  4.71844785e-16  6.00000000e-01]
# Data point :  [1 1 6]
# The dot product is :  0.7000000000000095
# Data index :  1
# weights :  [-2.90000000e+00  4.71844785e-16  6.00000000e-01]
# Data point :  [1 7 2]
# The dot product is :  -1.6999999999999946
# Data index :  2
# weights :  [-2.8  0.7  0.8]
# Data point :  [1 8 9]
# The dot product is :  10.00000000000002
# Data index :  3
# weights :  [-2.8  0.7  0.8]
# Data point :  [1 9 9]
# The dot product is :  10.700000000000019
# Data index :  4
# weights :  [-2.8  0.7  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  0.5999999999999983
# Data index :  5
# weights :  [-2.8  0.7  0.8]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.2000000000000035
# Data index :  6
# weights :  [-2.9  0.5  0.6]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.5000000000000071
# Data index :  7
# weights :  [-3.   0.3  0.2]
# Data point :  [-1 -7 -1]
# The dot product is :  0.6999999999999963
#
#
#
# Epoch :  43
# Data index :  0
# weights :  [-3.   0.3  0.2]
# Data point :  [1 1 6]
# The dot product is :  -1.49999999999999
# Data index :  1
# weights :  [-2.9  0.4  0.8]
# Data point :  [1 7 2]
# The dot product is :  1.500000000000006
# Data index :  2
# weights :  [-2.9  0.4  0.8]
# Data point :  [1 8 9]
# The dot product is :  7.5000000000000195
# Data index :  3
# weights :  [-2.9  0.4  0.8]
# Data point :  [1 9 9]
# The dot product is :  7.90000000000002
# Data index :  4
# weights :  [-2.9  0.4  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  1.2999999999999985
# Data index :  5
# weights :  [-2.9  0.4  0.8]
# Data point :  [-1 -2 -2]
# The dot product is :  0.49999999999999667
# Data index :  6
# weights :  [-2.9  0.4  0.8]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.1000000000000072
# Data index :  7
# weights :  [-3.   0.2  0.4]
# Data point :  [-1 -7 -1]
# The dot product is :  1.1999999999999962
#
#
#
# Epoch :  44
# Data index :  0
# weights :  [-3.   0.2  0.4]
# Data point :  [1 1 6]
# The dot product is :  -0.39999999999998925
# Data index :  1
# weights :  [-2.9  0.3  1. ]
# Data point :  [1 7 2]
# The dot product is :  1.200000000000006
# Data index :  2
# weights :  [-2.9  0.3  1. ]
# Data point :  [1 8 9]
# The dot product is :  8.500000000000021
# Data index :  3
# weights :  [-2.9  0.3  1. ]
# Data point :  [1 9 9]
# The dot product is :  8.800000000000022
# Data index :  4
# weights :  [-2.9  0.3  1. ]
# Data point :  [-1 -2 -1]
# The dot product is :  1.2999999999999983
# Data index :  5
# weights :  [-2.9  0.3  1. ]
# Data point :  [-1 -2 -2]
# The dot product is :  0.29999999999999627
# Data index :  6
# weights :  [-2.9  0.3  1. ]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.7000000000000077
# Data index :  7
# weights :  [-3.   0.1  0.6]
# Data point :  [-1 -7 -1]
# The dot product is :  1.6999999999999962
#
#
#
# Epoch :  45
# Data index :  0
# weights :  [-3.   0.1  0.6]
# Data point :  [1 1 6]
# The dot product is :  0.7000000000000113
# Data index :  1
# weights :  [-3.   0.1  0.6]
# Data point :  [1 7 2]
# The dot product is :  -1.099999999999994
# Data index :  2
# weights :  [-2.9  0.8  0.8]
# Data point :  [1 8 9]
# The dot product is :  10.70000000000002
# Data index :  3
# weights :  [-2.9  0.8  0.8]
# Data point :  [1 9 9]
# The dot product is :  11.500000000000021
# Data index :  4
# weights :  [-2.9  0.8  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  0.4999999999999982
# Data index :  5
# weights :  [-2.9  0.8  0.8]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.3000000000000038
# Data index :  6
# weights :  [-3.   0.6  0.6]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.6000000000000081
# Data index :  7
# weights :  [-3.1  0.4  0.2]
# Data point :  [-1 -7 -1]
# The dot product is :  0.09999999999999554
#
#
#
# Epoch :  46
# Data index :  0
# weights :  [-3.1  0.4  0.2]
# Data point :  [1 1 6]
# The dot product is :  -1.4999999999999887
# Data index :  1
# weights :  [-3.   0.5  0.8]
# Data point :  [1 7 2]
# The dot product is :  2.1000000000000068
# Data index :  2
# weights :  [-3.   0.5  0.8]
# Data point :  [1 8 9]
# The dot product is :  8.200000000000022
# Data index :  3
# weights :  [-3.   0.5  0.8]
# Data point :  [1 9 9]
# The dot product is :  8.700000000000024
# Data index :  4
# weights :  [-3.   0.5  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  1.199999999999998
# Data index :  5
# weights :  [-3.   0.5  0.8]
# Data point :  [-1 -2 -2]
# The dot product is :  0.3999999999999957
# Data index :  6
# weights :  [-3.   0.5  0.8]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.2000000000000086
# Data index :  7
# weights :  [-3.1  0.3  0.4]
# Data point :  [-1 -7 -1]
# The dot product is :  0.5999999999999956
#
#
#
# Epoch :  47
# Data index :  0
# weights :  [-3.1  0.3  0.4]
# Data point :  [1 1 6]
# The dot product is :  -0.3999999999999879
# Data index :  1
# weights :  [-3.   0.4  1. ]
# Data point :  [1 7 2]
# The dot product is :  1.8000000000000074
# Data index :  2
# weights :  [-3.   0.4  1. ]
# Data point :  [1 8 9]
# The dot product is :  9.200000000000022
# Data index :  3
# weights :  [-3.   0.4  1. ]
# Data point :  [1 9 9]
# The dot product is :  9.600000000000023
# Data index :  4
# weights :  [-3.   0.4  1. ]
# Data point :  [-1 -2 -1]
# The dot product is :  1.199999999999998
# Data index :  5
# weights :  [-3.   0.4  1. ]
# Data point :  [-1 -2 -2]
# The dot product is :  0.19999999999999574
# Data index :  6
# weights :  [-3.   0.4  1. ]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.8000000000000087
# Data index :  7
# weights :  [-3.1  0.2  0.6]
# Data point :  [-1 -7 -1]
# The dot product is :  1.0999999999999952
#
#
#
# Epoch :  48
# Data index :  0
# weights :  [-3.1  0.2  0.6]
# Data point :  [1 1 6]
# The dot product is :  0.7000000000000122
# Data index :  1
# weights :  [-3.1  0.2  0.6]
# Data point :  [1 7 2]
# The dot product is :  -0.4999999999999931
# Data index :  2
# weights :  [-3.   0.9  0.8]
# Data point :  [1 8 9]
# The dot product is :  11.400000000000023
# Data index :  3
# weights :  [-3.   0.9  0.8]
# Data point :  [1 9 9]
# The dot product is :  12.300000000000024
# Data index :  4
# weights :  [-3.   0.9  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  0.3999999999999979
# Data index :  5
# weights :  [-3.   0.9  0.8]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.40000000000000435
# Data index :  6
# weights :  [-3.1  0.7  0.6]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.7000000000000091
# Data index :  7
# weights :  [-3.2  0.5  0.2]
# Data point :  [-1 -7 -1]
# The dot product is :  -0.5000000000000052
#
#
#
# Epoch :  49
# Data index :  0
# weights :  [-3.3 -0.2  0.1]
# Data point :  [1 1 6]
# The dot product is :  -2.899999999999987
# Data index :  1
# weights :  [-3.2 -0.1  0.7]
# Data point :  [1 7 2]
# The dot product is :  -2.4999999999999925
# Data index :  2
# weights :  [-3.1  0.6  0.9]
# Data point :  [1 8 9]
# The dot product is :  9.800000000000026
# Data index :  3
# weights :  [-3.1  0.6  0.9]
# Data point :  [1 9 9]
# The dot product is :  10.400000000000025
# Data index :  4
# weights :  [-3.1  0.6  0.9]
# Data point :  [-1 -2 -1]
# The dot product is :  0.9999999999999978
# Data index :  5
# weights :  [-3.1  0.6  0.9]
# Data point :  [-1 -2 -2]
# The dot product is :  0.09999999999999543
# Data index :  6
# weights :  [-3.1  0.6  0.9]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.7000000000000093
# Data index :  7
# weights :  [-3.2  0.4  0.5]
# Data point :  [-1 -7 -1]
# The dot product is :  -0.10000000000000508
#
#
#
# Epoch :  50
# Data index :  0
# weights :  [-3.3 -0.3  0.4]
# Data point :  [1 1 6]
# The dot product is :  -1.1999999999999869
# Data index :  1
# weights :  [-3.2 -0.2  1. ]
# Data point :  [1 7 2]
# The dot product is :  -2.599999999999993
# Data index :  2
# weights :  [-3.1  0.5  1.2]
# Data point :  [1 8 9]
# The dot product is :  11.700000000000026
# Data index :  3
# weights :  [-3.1  0.5  1.2]
# Data point :  [1 9 9]
# The dot product is :  12.200000000000028
# Data index :  4
# weights :  [-3.1  0.5  1.2]
# Data point :  [-1 -2 -1]
# The dot product is :  0.8999999999999977
# Data index :  5
# weights :  [-3.1  0.5  1.2]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.3000000000000047
# Data index :  6
# weights :  [-3.2  0.3  1. ]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.4000000000000097
# Data index :  7
# weights :  [-3.3  0.1  0.6]
# Data point :  [-1 -7 -1]
# The dot product is :  1.9999999999999947
#
#
#
# Epoch :  51
# Data index :  0
# weights :  [-3.3  0.1  0.6]
# Data point :  [1 1 6]
# The dot product is :  0.4000000000000137
# Data index :  1
# weights :  [-3.3  0.1  0.6]
# Data point :  [1 7 2]
# The dot product is :  -1.3999999999999921
# Data index :  2
# weights :  [-3.2  0.8  0.8]
# Data point :  [1 8 9]
# The dot product is :  10.400000000000027
# Data index :  3
# weights :  [-3.2  0.8  0.8]
# Data point :  [1 9 9]
# The dot product is :  11.200000000000028
# Data index :  4
# weights :  [-3.2  0.8  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  0.7999999999999976
# Data index :  5
# weights :  [-3.2  0.8  0.8]
# Data point :  [-1 -2 -2]
# The dot product is :  -4.884981308350689e-15
# Data index :  6
# weights :  [-3.3  0.6  0.6]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.30000000000001004
# Data index :  7
# weights :  [-3.4  0.4  0.2]
# Data point :  [-1 -7 -1]
# The dot product is :  0.399999999999994
#
#
#
# Epoch :  52
# Data index :  0
# weights :  [-3.4  0.4  0.2]
# Data point :  [1 1 6]
# The dot product is :  -1.7999999999999858
# Data index :  1
# weights :  [-3.3  0.5  0.8]
# Data point :  [1 7 2]
# The dot product is :  1.800000000000009
# Data index :  2
# weights :  [-3.3  0.5  0.8]
# Data point :  [1 8 9]
# The dot product is :  7.900000000000028
# Data index :  3
# weights :  [-3.3  0.5  0.8]
# Data point :  [1 9 9]
# The dot product is :  8.400000000000029
# Data index :  4
# weights :  [-3.3  0.5  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  1.4999999999999973
# Data index :  5
# weights :  [-3.3  0.5  0.8]
# Data point :  [-1 -2 -2]
# The dot product is :  0.6999999999999946
# Data index :  6
# weights :  [-3.3  0.5  0.8]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.9000000000000106
# Data index :  7
# weights :  [-3.4  0.3  0.4]
# Data point :  [-1 -7 -1]
# The dot product is :  0.8999999999999937
#
#
#
# Epoch :  53
# Data index :  0
# weights :  [-3.4  0.3  0.4]
# Data point :  [1 1 6]
# The dot product is :  -0.6999999999999855
# Data index :  1
# weights :  [-3.3  0.4  1. ]
# Data point :  [1 7 2]
# The dot product is :  1.5000000000000093
# Data index :  2
# weights :  [-3.3  0.4  1. ]
# Data point :  [1 8 9]
# The dot product is :  8.90000000000003
# Data index :  3
# weights :  [-3.3  0.4  1. ]
# Data point :  [1 9 9]
# The dot product is :  9.300000000000031
# Data index :  4
# weights :  [-3.3  0.4  1. ]
# Data point :  [-1 -2 -1]
# The dot product is :  1.4999999999999973
# Data index :  5
# weights :  [-3.3  0.4  1. ]
# Data point :  [-1 -2 -2]
# The dot product is :  0.49999999999999467
# Data index :  6
# weights :  [-3.3  0.4  1. ]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.5000000000000107
# Data index :  7
# weights :  [-3.4  0.2  0.6]
# Data point :  [-1 -7 -1]
# The dot product is :  1.3999999999999937
#
#
#
# Epoch :  54
# Data index :  0
# weights :  [-3.4  0.2  0.6]
# Data point :  [1 1 6]
# The dot product is :  0.40000000000001457
# Data index :  1
# weights :  [-3.4  0.2  0.6]
# Data point :  [1 7 2]
# The dot product is :  -0.7999999999999909
# Data index :  2
# weights :  [-3.3  0.9  0.8]
# Data point :  [1 8 9]
# The dot product is :  11.10000000000003
# Data index :  3
# weights :  [-3.3  0.9  0.8]
# Data point :  [1 9 9]
# The dot product is :  12.000000000000028
# Data index :  4
# weights :  [-3.3  0.9  0.8]
# Data point :  [-1 -2 -1]
# The dot product is :  0.6999999999999973
# Data index :  5
# weights :  [-3.3  0.9  0.8]
# Data point :  [-1 -2 -2]
# The dot product is :  -0.10000000000000542
# Data index :  6
# weights :  [-3.4  0.7  0.6]
# Data point :  [-1 -2 -4]
# The dot product is :  -0.400000000000011
# Data index :  7
# weights :  [-3.5  0.5  0.2]
# Data point :  [-1 -7 -1]
# The dot product is :  -0.20000000000000717
#
#
#
# Epoch :  55
# Data index :  0
# weights :  [-3.6 -0.2  0.1]
# Data point :  [1 1 6]
# The dot product is :  -3.199999999999985
# Data index :  1
# weights :  [-3.5 -0.1  0.7]
# Data point :  [1 7 2]
# The dot product is :  -2.79999999999999
# Data index :  2
# weights :  [-3.4  0.6  0.9]
# Data point :  [1 8 9]
# The dot product is :  9.50000000000003
# Data index :  3
# weights :  [-3.4  0.6  0.9]
# Data point :  [1 9 9]
# The dot product is :  10.10000000000003
# Data index :  4
# weights :  [-3.4  0.6  0.9]
# Data point :  [-1 -2 -1]
# The dot product is :  1.2999999999999974
# Data index :  5
# weights :  [-3.4  0.6  0.9]
# Data point :  [-1 -2 -2]
# The dot product is :  0.3999999999999946
# Data index :  6
# weights :  [-3.4  0.6  0.9]
# Data point :  [-1 -2 -4]
# The dot product is :  -1.400000000000011
# Data index :  7
# weights :  [-3.5  0.4  0.5]
# Data point :  [-1 -7 -1]
# The dot product is :  0.19999999999999296
#
#
#
# Epoch :  56
# Data index :  0
# weights :  [-3.5  0.4  0.5]
# Data point :  [1 1 6]
# The dot product is :  -0.0999999999999841
# Data index :  1
# weights :  [-3.4  0.5  1.1]
# Data point :  [1 7 2]
# The dot product is :  2.30000000000001
# Data index :  2
# weights :  [-3.4  0.5  1.1]
# Data point :  [1 8 9]
# The dot product is :  10.50000000000003
# Data index :  3
# weights :  [-3.4  0.5  1.1]
# Data point :  [1 9 9]
# The dot product is :  11.000000000000032
# Data index :  4
# weights :  [-3.4  0.5  1.1]
# Data point :  [-1 -2 -1]
# The dot product is :  1.2999999999999972
# Data index :  5
# weights :  [-3.4  0.5  1.1]
# Data point :  [-1 -2 -2]
# The dot product is :  0.1999999999999944
# Data index :  6
# weights :  [-3.4  0.5  1.1]
# Data point :  [-1 -2 -4]
# The dot product is :  -2.000000000000011
# Data index :  7
# weights :  [-3.5  0.3  0.7]
# Data point :  [-1 -7 -1]
# The dot product is :  0.6999999999999927
#
#
#
# Epoch :  57
# Data index :  0
# weights :  [-3.5  0.3  0.7]
# Data point :  [1 1 6]
# The dot product is :  1.000000000000015
# Data index :  1
# weights :  [-3.5  0.3  0.7]
# Data point :  [1 7 2]
# The dot product is :  9.992007221626409e-15
# Data index :  2
# weights :  [-3.5  0.3  0.7]
# Data point :  [1 8 9]
# The dot product is :  5.2000000000000295
# Data index :  3
# weights :  [-3.5  0.3  0.7]
# Data point :  [1 9 9]
# The dot product is :  5.50000000000003
# Data index :  4
# weights :  [-3.5  0.3  0.7]
# Data point :  [-1 -2 -1]
# The dot product is :  2.199999999999997
# Data index :  5
# weights :  [-3.5  0.3  0.7]
# Data point :  [-1 -2 -2]
# The dot product is :  1.4999999999999944
# Data index :  6
# weights :  [-3.5  0.3  0.7]
# Data point :  [-1 -2 -4]
# The dot product is :  0.09999999999998899
# Data index :  7
# weights :  [-3.5  0.3  0.7]
# Data point :  [-1 -7 -1]
# The dot product is :  0.6999999999999927
# The final weight vector is :  [-3.5  0.3  0.7]
# (8, 3)
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:43: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
